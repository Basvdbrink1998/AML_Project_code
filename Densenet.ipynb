# %%
# Basic python packages
import os
from os import listdir
from os.path import isfile, join
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from collections import defaultdict
import glob

# General machine learning packages
from sklearn.model_selection import train_test_split

# Packages related to images
from PIL import Image
import PIL

# Packages for neural networks
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from keras.layers import Dense, Dropout, Conv2D, MaxPool2D, Flatten, Embedding
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.layers import Dense,GlobalAveragePooling2D,Convolution2D,BatchNormalization
from tensorflow.keras.layers import Flatten,MaxPooling2D,Dropout

from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.densenet import preprocess_input
from tensorflow.keras.models import Model

# %%
# Check if GPU works
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#Paths to different folders/files
image_dir = "../train_set/train_set"
test_image_dir = "../test_set"
labels_file = "../train_labels.csv"
training_path = '../training_data/'
validation_path = '../validation_data/'

img_size = (200, 200) #Size of the input of the neural networks
IMG_SHAPE = img_size + (3,)
batch_size = 32
n_labels = 80

# %%
labels = pd.read_csv(labels_file)
labels
# Out:
#               img_name  label
# 0          train_1.jpg     21
# 1          train_2.jpg     29
# 2          train_3.jpg     17
# 3          train_4.jpg     21
# 4          train_5.jpg     50
# ...                ...    ...
# 30607  train_30608.jpg     53
# 30608  train_30609.jpg     18
# 30609  train_30610.jpg      6
# 30610  train_30611.jpg     21
# 30611  train_30612.jpg     24
#
# [30612 rows x 2 columns]

# %%
def plot_random_images(img_names, n_x=2, n_y=2, seed=0):
    """
    Plots random images from de data set in a n_x by n_y grid

    :image_names: List with the names of all images
    :n_x: Height of the grid
    :n_x: Width of the grid
    :seed: Seed for the random sample
    :return: nothing
    """ 
    f, axs = plt.subplots(n_x, n_y)
    sample = img_names.sample(n_x * n_y, random_state=seed)
    c = 0
    for x in range(n_x):
        for y in range(n_y):
            img = plt.imread(image_dir + "/" + sample.iloc[c])
            axs[x, y].imshow(img)
            axs[x, y].axis('off')
            c += 1

plot_random_images(labels["img_name"], 3, 5)

# %% [markdown]
# # Image size
# Most machine learning requires that the input is always of the same size. Because our images are not always of the same size. We have to resize them

# %%
def resize_images(img_names, img_dir, new_img_dir):
    #Deprecated, replaced by the flow from directory
    for img in img_names:
        Image.open(img_dir + "/" + img).resize(img_size).save(new_img_dir + "/" + img)

# resize_images(labels["img_name"], image_dir, resized_train_dir)

# %% [markdown]
# # Split
# To test our models locally, we must split our data into a train and test set

# %%
# X_train, X_test, y_train, y_test = train_test_split(labels["img_name"].to_numpy(), labels["label"].to_numpy(), test_size=0.2, random_state=42)
# y_train

# %% [markdown]
# # Reformat data for learning
# To be able to load the data with a generator. We must split the training and validation data and place them into a folder based on their label.

# %%
def generate_label_folders(image_path, image_names, image_labels, destination_path):
    """
    Splits a single folder with images into multiple folders where images are placed based on their labels.

    :image_path: path to the folder with the images
    :image_names: A numpy array with the names of all images
    :image_labels: A numpy array with the labels of all images
    :destination_path: Path of the folder where the images are placed into
    :return: Nothing
    """ 
    for i in range(len(image_names)):
        # Check if the directory exists. Else, make one
        isExist = os.path.exists(destination_path + str(image_labels[i]))
        if not isExist:
            os.makedirs(destination_path + str(image_labels[i]))
            
        # Copy the image
        img = Image.open(image_path + "/" + image_names[i])
        img.save(destination_path + "/" + str(image_labels[i]) + "/" + image_names[i])
        

# generate_label_folders(image_dir, X_train, y_train, training_path)
# generate_label_folders(image_dir, X_test, y_test, validation_path)

# %% [markdown]
# # Image Loading
# Because the dataset is so large, we cant just load it into our memory. Instead we generate batches of images. These images are then altered a little bit to create higher variance between images and artificially increase the size of our training data.

# %%
def normalize(image):
    image = tf.cast(image, tf.float32)
    image = (image / 127.5) - 1
    return image

train_datagen = ImageDataGenerator(
        preprocessing_function=normalize,
        shear_range=2,
        zoom_range=0.2,
        rotation_range = 3,
        width_shift_range=0.2,
        height_shift_range=0.2,
        brightness_range=[0.6,1.3],
        horizontal_flip=True,
        fill_mode='nearest')

test_datagen = ImageDataGenerator(
        preprocessing_function=normalize)

train_generator = train_datagen.flow_from_directory(
        training_path,
        target_size=img_size,
        batch_size=batch_size,
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_path,
        target_size=img_size,
        batch_size=batch_size,
        shuffle=True,
        class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
        test_image_dir,
        target_size=img_size,
        batch_size=batch_size,
        shuffle=False)
# Out:
# Found 24489 images belonging to 80 classes.
# Found 6123 images belonging to 80 classes.
# Found 7653 images belonging to 1 classes.

# %%
fig, ax = plt.subplots(nrows=1, ncols=4, figsize=(15,15))

for i in range(4):

    # convert to unsigned integers for plotting
    image = next(train_generator)[0][0]
    # changing size from (1, 200, 200, 3) to (200, 200, 3) for plotting the image
    image = np.squeeze(image) * 0.5 + 0.5
    # plot raw pixel data
    ax[i].imshow(image)
    ax[i].axis('off')

# %%
def train_model(model, steps_per_epoch=150, epochs=3, validation_steps=20, workers=7, checkpoint_loc=""):
    """
    Trains a given model

    :steps_per_epoch: Amount of batches uploaded per epoch. Cant be higher than +- 200
    :epochs: Amount of times the model trains on the data
    :validation_steps: Amount of batches used for validation. Cant be higher than +- 50
    :workers: Amount of processes used to load the data
    :checkpoint_loc: Place for the model checkpoints to be saved
    :return: The trained model and some training data
    """ 
    # Create a callback that saves the model's weights
    cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_loc,
                                                     save_weights_only=True,
                                                     verbose=1)
    begin_time = datetime.datetime.now()
    history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=epochs, validation_data=validation_generator, validation_steps=validation_steps, workers=workers, callbacks=[cp_callback])
    print(datetime.datetime.now() - begin_time)
    return (model, history)

# %%
def plot_history(history):
    #Plots the training data.
    plt.plot(history.history['accuracy'], label='accuracy')
    plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.show()

# %% [markdown]
# # Example: simple pre-trained CNN

# %%
def make_densenet():
    model_d=DenseNet121(weights='imagenet',include_top=False, input_shape=IMG_SHAPE) 

    x=model_d.output

    x= GlobalAveragePooling2D()(x)
    x= BatchNormalization()(x)
    x= Dropout(0.5)(x)
    x= Dense(1024,activation='relu')(x) 
    x= Dense(512,activation='relu')(x) 
    x= BatchNormalization()(x)
    x= Dropout(0.5)(x)
    preds=Dense(80,activation='softmax')(x) #FC-layer
    model=Model(inputs=model_d.input,outputs=preds)
    
    for layer in model.layers[:-8]:
        layer.trainable=False
    
    for layer in model.layers[-8:]:
        layer.trainable=True
        
    base_learning_rate = 0.0001
    model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=base_learning_rate),loss='categorical_crossentropy',metrics=['accuracy'])
    return model

densenet = make_densenet()
densenet.load_weights("../Model_weights/Densenet/")

# MNV2model.summary()

# %%
densenet, history_MNV2 = train_model(densenet, steps_per_epoch=150, epochs=30, checkpoint_loc="../Model_weights/Densenet/")
# Out:
# Epoch 1/30
# 150/150 [==============================] - ETA: 0s - loss: 3.0937 - accuracy: 0.2731
# Epoch 00001: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 42s 275ms/step - loss: 3.0937 - accuracy: 0.2731 - val_loss: 2.4614 - val_accuracy: 0.4094
# Epoch 2/30
# 150/150 [==============================] - ETA: 0s - loss: 3.0710 - accuracy: 0.2858
# Epoch 00002: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 41s 270ms/step - loss: 3.0710 - accuracy: 0.2858 - val_loss: 2.3341 - val_accuracy: 0.4344
# Epoch 3/30
# 150/150 [==============================] - ETA: 0s - loss: 3.0140 - accuracy: 0.2942
# Epoch 00003: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 41s 272ms/step - loss: 3.0140 - accuracy: 0.2942 - val_loss: 2.1895 - val_accuracy: 0.4719
# Epoch 4/30
# 150/150 [==============================] - ETA: 0s - loss: 2.9932 - accuracy: 0.2917
# Epoch 00004: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 41s 270ms/step - loss: 2.9932 - accuracy: 0.2917 - val_loss: 2.2233 - val_accuracy: 0.4625
# Epoch 5/30
# 150/150 [==============================] - ETA: 0s - loss: 2.9605 - accuracy: 0.2940
# Epoch 00005: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 41s 271ms/step - loss: 2.9605 - accuracy: 0.2940 - val_loss: 2.2740 - val_accuracy: 0.4375
# Epoch 6/30
# 150/150 [==============================] - ETA: 0s - loss: 2.9667 - accuracy: 0.2887 ETA:  -
# Epoch 00006: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 41s 271ms/step - loss: 2.9667 - accuracy: 0.2887 - val_loss: 2.1673 - val_accuracy: 0.4688
# Epoch 7/30
# 150/150 [==============================] - ETA: 0s - loss: 2.8521 - accuracy: 0.3148
# Epoch 00007: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 42s 274ms/step - loss: 2.8521 - accuracy: 0.3148 - val_loss: 2.2039 - val_accuracy: 0.4359
# Epoch 8/30
# 150/150 [==============================] - ETA: 0s - loss: 2.8692 - accuracy: 0.3100 ETA: 4s - loss: 2.8656 - accuracy:  - ETA: 3s - los
# Epoch 00008: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 41s 271ms/step - loss: 2.8692 - accuracy: 0.3100 - val_loss: 2.0418 - val_accuracy: 0.4906
# Epoch 9/30
# 150/150 [==============================] - ETA: 0s - loss: 2.7731 - accuracy: 0.3324
# Epoch 00009: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 42s 273ms/step - loss: 2.7731 - accuracy: 0.3324 - val_loss: 2.2017 - val_accuracy: 0.4594
# Epoch 10/30
# 150/150 [==============================] - ETA: 0s - loss: 2.7126 - accuracy: 0.3410
# Epoch 00010: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 42s 276ms/step - loss: 2.7126 - accuracy: 0.3410 - val_loss: 2.1978 - val_accuracy: 0.4703
# Epoch 11/30
# 150/150 [==============================] - ETA: 0s - loss: 2.7790 - accuracy: 0.3275
# Epoch 00011: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 42s 271ms/step - loss: 2.7790 - accuracy: 0.3275 - val_loss: 2.0373 - val_accuracy: 0.5125
# Epoch 12/30
# 150/150 [==============================] - ETA: 0s - loss: 2.7093 - accuracy: 0.3427
# Epoch 00012: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 41s 272ms/step - loss: 2.7093 - accuracy: 0.3427 - val_loss: 2.2163 - val_accuracy: 0.4688
# Epoch 13/30
# 150/150 [==============================] - ETA: 0s - loss: 2.6701 - accuracy: 0.3481
# Epoch 00013: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 42s 274ms/step - loss: 2.6701 - accuracy: 0.3481 - val_loss: 2.0547 - val_accuracy: 0.4953
# Epoch 14/30
# 150/150 [==============================] - ETA: 0s - loss: 2.7037 - accuracy: 0.3427
# Epoch 00014: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 42s 271ms/step - loss: 2.7037 - accuracy: 0.3427 - val_loss: 2.1546 - val_accuracy: 0.4828
# Epoch 15/30
# 150/150 [==============================] - ETA: 0s - loss: 2.6460 - accuracy: 0.3513
# Epoch 00015: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 41s 270ms/step - loss: 2.6460 - accuracy: 0.3513 - val_loss: 2.1045 - val_accuracy: 0.4891
# Epoch 16/30
# 150/150 [==============================] - ETA: 0s - loss: 2.6182 - accuracy: 0.3569
# Epoch 00016: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 42s 275ms/step - loss: 2.6182 - accuracy: 0.3569 - val_loss: 2.1700 - val_accuracy: 0.4656
# Epoch 17/30
# 150/150 [==============================] - ETA: 0s - loss: 2.6186 - accuracy: 0.3521
# Epoch 00017: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 42s 271ms/step - loss: 2.6186 - accuracy: 0.3521 - val_loss: 1.8680 - val_accuracy: 0.5422
# Epoch 18/30
# 150/150 [==============================] - ETA: 0s - loss: 2.6337 - accuracy: 0.3554
# Epoch 00018: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 41s 271ms/step - loss: 2.6337 - accuracy: 0.3554 - val_loss: 2.0873 - val_accuracy: 0.5063
# Epoch 19/30
# 150/150 [==============================] - ETA: 0s - loss: 2.6074 - accuracy: 0.3690
# Epoch 00019: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 41s 271ms/step - loss: 2.6074 - accuracy: 0.3690 - val_loss: 2.1102 - val_accuracy: 0.4969
# Epoch 20/30
# 150/150 [==============================] - ETA: 0s - loss: 2.6110 - accuracy: 0.3600
# Epoch 00020: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 42s 274ms/step - loss: 2.6110 - accuracy: 0.3600 - val_loss: 1.9707 - val_accuracy: 0.5250
# Epoch 21/30
# 150/150 [==============================] - ETA: 0s - loss: 2.5721 - accuracy: 0.3708
# Epoch 00021: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 42s 273ms/step - loss: 2.5721 - accuracy: 0.3708 - val_loss: 2.1280 - val_accuracy: 0.4828
# Epoch 22/30
# 150/150 [==============================] - ETA: 0s - loss: 2.5785 - accuracy: 0.3695
# Epoch 00022: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 42s 274ms/step - loss: 2.5785 - accuracy: 0.3695 - val_loss: 2.0737 - val_accuracy: 0.4859
# Epoch 23/30
# 150/150 [==============================] - ETA: 0s - loss: 2.5362 - accuracy: 0.3792
# Epoch 00023: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 41s 269ms/step - loss: 2.5362 - accuracy: 0.3792 - val_loss: 2.1410 - val_accuracy: 0.4734
# Epoch 24/30
# 150/150 [==============================] - ETA: 0s - loss: 2.5373 - accuracy: 0.3825
# Epoch 00024: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 41s 269ms/step - loss: 2.5373 - accuracy: 0.3825 - val_loss: 1.8473 - val_accuracy: 0.5297
# Epoch 25/30
# 150/150 [==============================] - ETA: 0s - loss: 2.5219 - accuracy: 0.3762
# Epoch 00025: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 41s 269ms/step - loss: 2.5219 - accuracy: 0.3762 - val_loss: 2.0004 - val_accuracy: 0.5078
# Epoch 26/30
# 150/150 [==============================] - ETA: 0s - loss: 2.4927 - accuracy: 0.3760
# Epoch 00026: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 41s 268ms/step - loss: 2.4927 - accuracy: 0.3760 - val_loss: 2.0171 - val_accuracy: 0.5125
# Epoch 27/30
# 150/150 [==============================] - ETA: 0s - loss: 2.5104 - accuracy: 0.3852
# Epoch 00027: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 41s 267ms/step - loss: 2.5104 - accuracy: 0.3852 - val_loss: 1.9371 - val_accuracy: 0.5250
# Epoch 28/30
# 150/150 [==============================] - ETA: 0s - loss: 2.4823 - accuracy: 0.3871
# Epoch 00028: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 41s 268ms/step - loss: 2.4823 - accuracy: 0.3871 - val_loss: 1.8984 - val_accuracy: 0.5234
# Epoch 29/30
# 150/150 [==============================] - ETA: 0s - loss: 2.5203 - accuracy: 0.3873
# Epoch 00029: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 41s 269ms/step - loss: 2.5203 - accuracy: 0.3873 - val_loss: 2.0016 - val_accuracy: 0.5063
# Epoch 30/30
# 150/150 [==============================] - ETA: 0s - loss: 2.4912 - accuracy: 0.3835
# Epoch 00030: saving model to ../Model_weights/Densenet2\
# 150/150 [==============================] - 41s 269ms/step - loss: 2.4912 - accuracy: 0.3835 - val_loss: 2.0014 - val_accuracy: 0.5031
# 0:20:42.864142

# %%
plot_history(history_MNV2)

# %% [markdown]
# # More models:

# %% [markdown]
# # Predict the test set
# We also have to predict the real test set and save the results to upload to kaggle

# %%
def predict_test(model):
    preds = model.predict(test_generator)
    preds_cls_idx = preds.argmax(axis=-1)
    idx_to_cls = {v: k for k, v in train_generator.class_indices.items()}
    preds_cls = np.vectorize(idx_to_cls.get)(preds_cls_idx)
    filenames_to_cls = list(zip(test_generator.filenames, preds_cls))
    
    l = []
    n = []
    for p in filenames_to_cls:
        n.append(p[0].split("\\")[-1])
        l.append(p[1])
    return pd.DataFrame(list(zip(n, l)), columns=['img_name','label'])

res = predict_test(densenet)
res.to_csv("sample_submission.csv", index=False)

# %%
MNV2model.predict(next(test_generator)[0]).max(axis=1)
# Out:
# array([0.15300915, 0.2815523 , 0.25540632, 0.60232705, 0.31349978,
#        0.15973873, 0.5036791 , 0.93991035, 0.2741486 , 0.11705089,
#        0.9990227 , 0.24005938, 0.40372372, 0.18074892, 0.91742414,
#        0.22677587, 0.22739498, 0.2126853 , 0.15897313, 0.45730296,
#        0.41209576, 0.47251552, 0.44185406, 0.63193166, 0.13468851,
#        0.9599018 , 0.1634099 , 0.6435081 , 0.3523767 , 0.27933908,
#        0.7724157 , 0.3269065 ], dtype=float32)
