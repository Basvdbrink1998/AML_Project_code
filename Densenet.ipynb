# %%
# Basic python packages
import os
from os import listdir
from os.path import isfile, join
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from collections import defaultdict
import glob

# General machine learning packages
from sklearn.model_selection import train_test_split

# Packages related to images
from PIL import Image
import PIL

# Packages for neural networks
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from keras.layers import Dense, Dropout, Conv2D, MaxPool2D, Flatten, Embedding
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.layers import Dense,GlobalAveragePooling2D,Convolution2D,BatchNormalization
from tensorflow.keras.layers import Flatten,MaxPooling2D,Dropout

from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.densenet import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.losses import CategoricalCrossentropy

from sklearn.metrics import confusion_matrix
import seaborn as sns

# %load_ext tensorboard

# %%
# Check if GPU works
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#Paths to different folders/files
image_dir = "../train_set/train_set"
test_image_dir = "../test_set"
labels_file = "../train_labels.csv"
training_path = '../total_data/'
validation_path = '../validation_data/'

img_size = (200, 200) #Size of the input of the neural networks
IMG_SHAPE = img_size + (3,)
batch_size = 64
n_labels = 80

# %%
labels = pd.read_csv(labels_file)
labels
# Out:
#               img_name  label
# 0          train_1.jpg     21
# 1          train_2.jpg     29
# 2          train_3.jpg     17
# 3          train_4.jpg     21
# 4          train_5.jpg     50
# ...                ...    ...
# 30607  train_30608.jpg     53
# 30608  train_30609.jpg     18
# 30609  train_30610.jpg      6
# 30610  train_30611.jpg     21
# 30611  train_30612.jpg     24
#
# [30612 rows x 2 columns]

# %%
def plot_random_images(img_names, n_x=2, n_y=2, seed=0):
    """
    Plots random images from de data set in a n_x by n_y grid

    :image_names: List with the names of all images
    :n_x: Height of the grid
    :n_x: Width of the grid
    :seed: Seed for the random sample
    :return: nothing
    """ 
    f, axs = plt.subplots(n_x, n_y)
    sample = img_names.sample(n_x * n_y, random_state=seed)
    c = 0
    for x in range(n_x):
        for y in range(n_y):
            img = plt.imread(image_dir + "/" + sample.iloc[c])
            axs[x, y].imshow(img)
            axs[x, y].axis('off')
            c += 1

plot_random_images(labels["img_name"], 3, 5)

# %% [markdown]
# # Image size
# Most machine learning requires that the input is always of the same size. Because our images are not always of the same size. We have to resize them

# %%
def resize_images(img_names, img_dir, new_img_dir):
    #Deprecated, replaced by the flow from directory
    for img in img_names:
        Image.open(img_dir + "/" + img).resize(img_size).save(new_img_dir + "/" + img)

# resize_images(labels["img_name"], image_dir, resized_train_dir)

# %% [markdown]
# # Split
# To test our models locally, we must split our data into a train and test set

# %%
# X_train, X_test, y_train, y_test = train_test_split(labels["img_name"].to_numpy(), labels["label"].to_numpy(), test_size=0.2, random_state=42)
# y_train

# %% [markdown]
# # Reformat data for learning
# To be able to load the data with a generator. We must split the training and validation data and place them into a folder based on their label.

# %%
def generate_label_folders(image_path, image_names, image_labels, destination_path):
    """
    Splits a single folder with images into multiple folders where images are placed based on their labels.

    :image_path: path to the folder with the images
    :image_names: A numpy array with the names of all images
    :image_labels: A numpy array with the labels of all images
    :destination_path: Path of the folder where the images are placed into
    :return: Nothing
    """ 
    for i in range(len(image_names)):
        # Check if the directory exists. Else, make one
        isExist = os.path.exists(destination_path + str(image_labels[i]))
        if not isExist:
            os.makedirs(destination_path + str(image_labels[i]))
            
        # Copy the image
        img = Image.open(image_path + "/" + image_names[i])
        img.save(destination_path + "/" + str(image_labels[i]) + "/" + image_names[i])
        

# generate_label_folders(image_dir, X_train, y_train, training_path)
# generate_label_folders(image_dir, X_test, y_test, validation_path)

# %% [markdown]
# # Image Loading
# Because the dataset is so large, we cant just load it into our memory. Instead we generate batches of images. These images are then altered a little bit to create higher variance between images and artificially increase the size of our training data.

# %%
def normalize(image):
    image = tf.cast(image, tf.float32)
    image = (image / 127.5) - 1
    return image

train_datagen = ImageDataGenerator(
        preprocessing_function=normalize,
        shear_range=30,
        zoom_range=0.1,
        rotation_range = 30,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest')

test_datagen = ImageDataGenerator(
        preprocessing_function=normalize)

train_generator = train_datagen.flow_from_directory(
        training_path,
        target_size=img_size,
        batch_size=batch_size,
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_path,
        target_size=img_size,
        batch_size=batch_size,
        shuffle=True,
        class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
        test_image_dir,
        target_size=img_size,
        batch_size=batch_size,
        shuffle=False)
# Out:
# Found 30612 images belonging to 80 classes.
# Found 0 images belonging to 0 classes.
# Found 7653 images belonging to 1 classes.

# %%
fig, ax = plt.subplots(nrows=1, ncols=4, figsize=(15,15))

for i in range(4):

    # convert to unsigned integers for plotting
    image = next(train_generator)[0][0]
    # changing size from (1, 200, 200, 3) to (200, 200, 3) for plotting the image
    image = np.squeeze(image) * 0.5 + 0.5
    # plot raw pixel data
    ax[i].imshow(image)
    ax[i].axis('off')

# %%
def train_model(model, steps_per_epoch=150, epochs=3, validation_steps=20, workers=7, checkpoint_loc=""):
    """
    Trains a given model

    :steps_per_epoch: Amount of batches uploaded per epoch. Cant be higher than +- 200
    :epochs: Amount of times the model trains on the data
    :validation_steps: Amount of batches used for validation. Cant be higher than +- 50
    :workers: Amount of processes used to load the data
    :checkpoint_loc: Place for the model checkpoints to be saved
    :return: The trained model and some training data
    """ 
    # Create a callback that saves the model's weights
    cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_loc,
                                                     save_weights_only=True,
                                                     verbose=1)
    log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
    begin_time = datetime.datetime.now()
    history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=epochs, validation_data=train_generator, validation_steps=validation_steps, workers=workers, callbacks=[cp_callback])
    print(datetime.datetime.now() - begin_time)
    return (model, history)

# %%
def plot_history(history):
    #Plots the training data.
    plt.plot(history.history['accuracy'], label='accuracy')
    plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.show()
    
def plot_multiple_histories(histories, labels):
    for l in labels:
        total = []
        for h in histories:
            total = total + h.history[l]
        plt.plot(total, label=l)
    
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.show()

# %% [markdown]
# # Example: simple pre-trained CNN

# %%
label_smoothing=0.1

# %%
def make_densenet():
    model_d=DenseNet121(weights='imagenet',include_top=False, input_shape=IMG_SHAPE) 

    x=model_d.output

    x= GlobalAveragePooling2D()(x)
    x= BatchNormalization()(x)
    x= Dropout(0.5)(x)
    x= Dense(2048,activation='relu')(x) 
    x= Dense(1024,activation='relu')(x) 
    x= Dense(512,activation='relu')(x) 
    x= BatchNormalization()(x)
    x= Dropout(0.5)(x)
    preds=Dense(80,activation='softmax')(x) #FC-layer
    model=Model(inputs=model_d.input,outputs=preds)
    
    for layer in model.layers[:-9]:
        layer.trainable=False
    
    for layer in model.layers[-9:]:
        layer.trainable=True
        
    model.compile(optimizer='adam',loss=CategoricalCrossentropy(label_smoothing=0.05),metrics=['accuracy'])
    return model

densenet = make_densenet()
densenet.load_weights("../Model_weights/Densenet7/")

# MNV2model.summary()
densenet_total_history = []
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.

# %%
densenet.save('saved_model/DenseNet2')
# Out:
# INFO:tensorflow:Assets written to: saved_model/DenseNet2\assets

# %%
densenet, history_densenet = train_model(densenet, steps_per_epoch=100, epochs=60, checkpoint_loc="../Model_weights/Densenet7/")

densenet_total_history.append(history_densenet)
# Out:
# Epoch 1/60
# 100/100 [==============================] - ETA: 0s - loss: 2.0333 - accuracy: 0.5409
# Epoch 00001: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 57s 554ms/step - loss: 2.0333 - accuracy: 0.5409 - val_loss: 1.5992 - val_accuracy: 0.6594
# Epoch 2/60
# 100/100 [==============================] - ETA: 0s - loss: 1.9701 - accuracy: 0.5633
# Epoch 00002: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 57s 561ms/step - loss: 1.9701 - accuracy: 0.5633 - val_loss: 1.5412 - val_accuracy: 0.6680
# Epoch 3/60
# 100/100 [==============================] - ETA: 0s - loss: 1.9689 - accuracy: 0.5520
# Epoch 00003: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 58s 563ms/step - loss: 1.9689 - accuracy: 0.5520 - val_loss: 1.4796 - val_accuracy: 0.6773
# Epoch 4/60
# 100/100 [==============================] - ETA: 0s - loss: 1.9744 - accuracy: 0.5558
# Epoch 00004: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 58s 562ms/step - loss: 1.9744 - accuracy: 0.5558 - val_loss: 1.4943 - val_accuracy: 0.6859
# Epoch 5/60
# 100/100 [==============================] - ETA: 0s - loss: 1.9931 - accuracy: 0.5516
# Epoch 00005: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 58s 562ms/step - loss: 1.9931 - accuracy: 0.5516 - val_loss: 1.4886 - val_accuracy: 0.6750
# Epoch 6/60
# 100/100 [==============================] - ETA: 0s - loss: 1.9593 - accuracy: 0.5619
# Epoch 00006: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 58s 566ms/step - loss: 1.9593 - accuracy: 0.5619 - val_loss: 1.4605 - val_accuracy: 0.7008
# Epoch 7/60
# 100/100 [==============================] - ETA: 0s - loss: 1.9473 - accuracy: 0.5678
# Epoch 00007: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 58s 563ms/step - loss: 1.9473 - accuracy: 0.5678 - val_loss: 1.5196 - val_accuracy: 0.6812
# Epoch 8/60
# 100/100 [==============================] - ETA: 0s - loss: 1.9720 - accuracy: 0.5524
# Epoch 00008: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 57s 561ms/step - loss: 1.9720 - accuracy: 0.5524 - val_loss: 1.4717 - val_accuracy: 0.6836
# Epoch 9/60
# 100/100 [==============================] - ETA: 0s - loss: 1.9858 - accuracy: 0.5422
# Epoch 00009: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 57s 559ms/step - loss: 1.9858 - accuracy: 0.5422 - val_loss: 1.5620 - val_accuracy: 0.6570
# Epoch 10/60
# 100/100 [==============================] - ETA: 0s - loss: 1.9889 - accuracy: 0.5537
# Epoch 00010: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 55s 540ms/step - loss: 1.9889 - accuracy: 0.5537 - val_loss: 1.5445 - val_accuracy: 0.6758
# Epoch 11/60
# 100/100 [==============================] - ETA: 0s - loss: 1.9435 - accuracy: 0.5558
# Epoch 00011: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 56s 545ms/step - loss: 1.9435 - accuracy: 0.5558 - val_loss: 1.4338 - val_accuracy: 0.7047
# Epoch 12/60
# 100/100 [==============================] - ETA: 0s - loss: 1.9607 - accuracy: 0.5544
# Epoch 00012: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 54s 528ms/step - loss: 1.9607 - accuracy: 0.5544 - val_loss: 1.4484 - val_accuracy: 0.6906
# Epoch 13/60
# 100/100 [==============================] - ETA: 0s - loss: 1.9616 - accuracy: 0.5580
# Epoch 00013: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 54s 529ms/step - loss: 1.9616 - accuracy: 0.5580 - val_loss: 1.3817 - val_accuracy: 0.7211
# Epoch 14/60
# 100/100 [==============================] - ETA: 0s - loss: 1.9035 - accuracy: 0.5658
# Epoch 00014: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 55s 536ms/step - loss: 1.9035 - accuracy: 0.5658 - val_loss: 1.4024 - val_accuracy: 0.7219
# Epoch 15/60
# 100/100 [==============================] - ETA: 0s - loss: 1.9426 - accuracy: 0.5653
# Epoch 00015: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 55s 536ms/step - loss: 1.9426 - accuracy: 0.5653 - val_loss: 1.4421 - val_accuracy: 0.7031
# Epoch 16/60
# 100/100 [==============================] - ETA: 0s - loss: 1.8981 - accuracy: 0.5813
# Epoch 00016: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 54s 527ms/step - loss: 1.8981 - accuracy: 0.5813 - val_loss: 1.4278 - val_accuracy: 0.7078
# Epoch 17/60
# 100/100 [==============================] - ETA: 0s - loss: 1.9277 - accuracy: 0.5697
# Epoch 00017: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 54s 531ms/step - loss: 1.9277 - accuracy: 0.5697 - val_loss: 1.3987 - val_accuracy: 0.7219
# Epoch 18/60
# 100/100 [==============================] - ETA: 0s - loss: 1.9273 - accuracy: 0.5673
# Epoch 00018: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 54s 532ms/step - loss: 1.9273 - accuracy: 0.5673 - val_loss: 1.4088 - val_accuracy: 0.7289
# Epoch 19/60
# 100/100 [==============================] - ETA: 0s - loss: 1.8750 - accuracy: 0.5821
# Epoch 00019: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 54s 529ms/step - loss: 1.8750 - accuracy: 0.5821 - val_loss: 1.3704 - val_accuracy: 0.7281
# Epoch 20/60
# 100/100 [==============================] - ETA: 0s - loss: 1.8432 - accuracy: 0.5886
# Epoch 00020: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 54s 528ms/step - loss: 1.8432 - accuracy: 0.5886 - val_loss: 1.3324 - val_accuracy: 0.7422
# Epoch 21/60
# 100/100 [==============================] - ETA: 0s - loss: 1.8859 - accuracy: 0.5722
# Epoch 00021: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 54s 531ms/step - loss: 1.8859 - accuracy: 0.5722 - val_loss: 1.3125 - val_accuracy: 0.7563
# Epoch 22/60
# 100/100 [==============================] - ETA: 0s - loss: 1.8757 - accuracy: 0.5816
# Epoch 00022: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 54s 533ms/step - loss: 1.8757 - accuracy: 0.5816 - val_loss: 1.3029 - val_accuracy: 0.7609
# Epoch 23/60
# 100/100 [==============================] - ETA: 0s - loss: 1.8574 - accuracy: 0.5878
# Epoch 00023: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 54s 532ms/step - loss: 1.8574 - accuracy: 0.5878 - val_loss: 1.3413 - val_accuracy: 0.7383
# Epoch 24/60
# 100/100 [==============================] - ETA: 0s - loss: 1.8406 - accuracy: 0.5886
# Epoch 00024: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 54s 532ms/step - loss: 1.8406 - accuracy: 0.5886 - val_loss: 1.3232 - val_accuracy: 0.7297
# Epoch 25/60
# 100/100 [==============================] - ETA: 0s - loss: 1.8721 - accuracy: 0.5856
# Epoch 00025: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 54s 531ms/step - loss: 1.8721 - accuracy: 0.5856 - val_loss: 1.3963 - val_accuracy: 0.7109
# Epoch 26/60
# 100/100 [==============================] - ETA: 0s - loss: 1.8387 - accuracy: 0.5930
# Epoch 00026: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 55s 536ms/step - loss: 1.8387 - accuracy: 0.5930 - val_loss: 1.3342 - val_accuracy: 0.7406
# Epoch 27/60
# 100/100 [==============================] - ETA: 0s - loss: 1.8527 - accuracy: 0.5889
# Epoch 00027: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 53s 523ms/step - loss: 1.8527 - accuracy: 0.5889 - val_loss: 1.3044 - val_accuracy: 0.7445
# Epoch 28/60
# 100/100 [==============================] - ETA: 0s - loss: 1.8089 - accuracy: 0.6061
# Epoch 00028: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 55s 537ms/step - loss: 1.8089 - accuracy: 0.6061 - val_loss: 1.3292 - val_accuracy: 0.7383
# Epoch 29/60
# 100/100 [==============================] - ETA: 0s - loss: 1.8270 - accuracy: 0.5997
# Epoch 00029: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 54s 530ms/step - loss: 1.8270 - accuracy: 0.5997 - val_loss: 1.3782 - val_accuracy: 0.7219
# Epoch 30/60
# 100/100 [==============================] - ETA: 0s - loss: 1.8223 - accuracy: 0.5839
# Epoch 00030: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 54s 531ms/step - loss: 1.8223 - accuracy: 0.5839 - val_loss: 1.2956 - val_accuracy: 0.7617
# Epoch 31/60
# 100/100 [==============================] - ETA: 0s - loss: 1.8285 - accuracy: 0.5944
# Epoch 00031: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 54s 528ms/step - loss: 1.8285 - accuracy: 0.5944 - val_loss: 1.2668 - val_accuracy: 0.7672
# Epoch 32/60
# 100/100 [==============================] - ETA: 0s - loss: 1.8061 - accuracy: 0.5953
# Epoch 00032: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 55s 535ms/step - loss: 1.8061 - accuracy: 0.5953 - val_loss: 1.2846 - val_accuracy: 0.7492
# Epoch 33/60
# 100/100 [==============================] - ETA: 0s - loss: 1.8053 - accuracy: 0.6057
# Epoch 00033: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 54s 530ms/step - loss: 1.8053 - accuracy: 0.6057 - val_loss: 1.2915 - val_accuracy: 0.7469
# Epoch 34/60
# 100/100 [==============================] - ETA: 0s - loss: 1.7961 - accuracy: 0.6048
# Epoch 00034: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 54s 531ms/step - loss: 1.7961 - accuracy: 0.6048 - val_loss: 1.2993 - val_accuracy: 0.7414
# Epoch 35/60
# 100/100 [==============================] - ETA: 0s - loss: 1.8065 - accuracy: 0.5978
# Epoch 00035: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 54s 531ms/step - loss: 1.8065 - accuracy: 0.5978 - val_loss: 1.2115 - val_accuracy: 0.7742
# Epoch 36/60
# 100/100 [==============================] - ETA: 0s - loss: 1.7971 - accuracy: 0.6014
# Epoch 00036: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 54s 533ms/step - loss: 1.7971 - accuracy: 0.6014 - val_loss: 1.2909 - val_accuracy: 0.7422
# Epoch 37/60
# 100/100 [==============================] - ETA: 0s - loss: 1.7911 - accuracy: 0.6066
# Epoch 00037: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 54s 530ms/step - loss: 1.7911 - accuracy: 0.6066 - val_loss: 1.1931 - val_accuracy: 0.7781
# Epoch 38/60
# 100/100 [==============================] - ETA: 0s - loss: 1.8126 - accuracy: 0.5958
# Epoch 00038: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 56s 546ms/step - loss: 1.8126 - accuracy: 0.5958 - val_loss: 1.2365 - val_accuracy: 0.7648
# Epoch 39/60
# 100/100 [==============================] - ETA: 0s - loss: 1.7880 - accuracy: 0.6028
# Epoch 00039: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 54s 529ms/step - loss: 1.7880 - accuracy: 0.6028 - val_loss: 1.2757 - val_accuracy: 0.7570
# Epoch 40/60
# 100/100 [==============================] - ETA: 0s - loss: 1.7639 - accuracy: 0.6106
# Epoch 00040: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 54s 532ms/step - loss: 1.7639 - accuracy: 0.6106 - val_loss: 1.3146 - val_accuracy: 0.7398
# Epoch 41/60
# 100/100 [==============================] - ETA: 0s - loss: 1.7291 - accuracy: 0.6158
# Epoch 00041: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 54s 530ms/step - loss: 1.7291 - accuracy: 0.6158 - val_loss: 1.2644 - val_accuracy: 0.7570
# Epoch 42/60
# 100/100 [==============================] - ETA: 0s - loss: 1.7827 - accuracy: 0.6041
# Epoch 00042: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 54s 530ms/step - loss: 1.7827 - accuracy: 0.6041 - val_loss: 1.2475 - val_accuracy: 0.7703
# Epoch 43/60
# 100/100 [==============================] - ETA: 0s - loss: 1.7304 - accuracy: 0.6172
# Epoch 00043: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 57s 562ms/step - loss: 1.7304 - accuracy: 0.6172 - val_loss: 1.1759 - val_accuracy: 0.7812
# Epoch 44/60
# 100/100 [==============================] - ETA: 0s - loss: 1.7583 - accuracy: 0.6123
# Epoch 00044: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 55s 539ms/step - loss: 1.7583 - accuracy: 0.6123 - val_loss: 1.1989 - val_accuracy: 0.7695
# Epoch 45/60
# 100/100 [==============================] - ETA: 0s - loss: 1.7697 - accuracy: 0.6065
# Epoch 00045: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 55s 538ms/step - loss: 1.7697 - accuracy: 0.6065 - val_loss: 1.2904 - val_accuracy: 0.7328
# Epoch 46/60
# 100/100 [==============================] - ETA: 0s - loss: 1.7401 - accuracy: 0.6220
# Epoch 00046: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 55s 542ms/step - loss: 1.7401 - accuracy: 0.6220 - val_loss: 1.2037 - val_accuracy: 0.7844
# Epoch 47/60
# 100/100 [==============================] - ETA: 0s - loss: 1.7517 - accuracy: 0.6134
# Epoch 00047: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 55s 540ms/step - loss: 1.7517 - accuracy: 0.6134 - val_loss: 1.1948 - val_accuracy: 0.7820
# Epoch 48/60
# 100/100 [==============================] - ETA: 0s - loss: 1.7456 - accuracy: 0.6166
# Epoch 00048: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 55s 542ms/step - loss: 1.7456 - accuracy: 0.6166 - val_loss: 1.2021 - val_accuracy: 0.7742
# Epoch 49/60
# 100/100 [==============================] - ETA: 0s - loss: 1.7183 - accuracy: 0.6208
# Epoch 00049: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 55s 543ms/step - loss: 1.7183 - accuracy: 0.6208 - val_loss: 1.1568 - val_accuracy: 0.7992
# Epoch 50/60
# 100/100 [==============================] - ETA: 0s - loss: 1.6951 - accuracy: 0.6238
# Epoch 00050: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 55s 540ms/step - loss: 1.6951 - accuracy: 0.6238 - val_loss: 1.1789 - val_accuracy: 0.7812
# Epoch 51/60
# 100/100 [==============================] - ETA: 0s - loss: 1.7104 - accuracy: 0.6278
# Epoch 00051: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 55s 540ms/step - loss: 1.7104 - accuracy: 0.6278 - val_loss: 1.2348 - val_accuracy: 0.7609
# Epoch 52/60
# 100/100 [==============================] - ETA: 0s - loss: 1.7205 - accuracy: 0.6269
# Epoch 00052: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 56s 550ms/step - loss: 1.7205 - accuracy: 0.6269 - val_loss: 1.1145 - val_accuracy: 0.8109
# Epoch 53/60
# 100/100 [==============================] - ETA: 0s - loss: 1.6932 - accuracy: 0.6305
# Epoch 00053: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 56s 544ms/step - loss: 1.6932 - accuracy: 0.6305 - val_loss: 1.1651 - val_accuracy: 0.7836
# Epoch 54/60
# 100/100 [==============================] - ETA: 0s - loss: 1.6760 - accuracy: 0.6322
# Epoch 00054: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 55s 541ms/step - loss: 1.6760 - accuracy: 0.6322 - val_loss: 1.1792 - val_accuracy: 0.7922
# Epoch 55/60
# 100/100 [==============================] - ETA: 0s - loss: 1.6854 - accuracy: 0.6298
# Epoch 00055: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 57s 554ms/step - loss: 1.6854 - accuracy: 0.6298 - val_loss: 1.1023 - val_accuracy: 0.8062
# Epoch 56/60
# 100/100 [==============================] - ETA: 0s - loss: 1.6730 - accuracy: 0.6298
# Epoch 00056: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 56s 542ms/step - loss: 1.6730 - accuracy: 0.6298 - val_loss: 1.1293 - val_accuracy: 0.7914
# Epoch 57/60
# 100/100 [==============================] - ETA: 0s - loss: 1.6728 - accuracy: 0.6389
# Epoch 00057: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 55s 540ms/step - loss: 1.6728 - accuracy: 0.6389 - val_loss: 1.1476 - val_accuracy: 0.7836
# Epoch 58/60
# 100/100 [==============================] - ETA: 0s - loss: 1.6906 - accuracy: 0.6283
# Epoch 00058: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 55s 540ms/step - loss: 1.6906 - accuracy: 0.6283 - val_loss: 1.1026 - val_accuracy: 0.8016
# Epoch 59/60
# 100/100 [==============================] - ETA: 0s - loss: 1.6462 - accuracy: 0.6492
# Epoch 00059: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 55s 541ms/step - loss: 1.6462 - accuracy: 0.6492 - val_loss: 1.1193 - val_accuracy: 0.7914
# Epoch 60/60
# 100/100 [==============================] - ETA: 0s - loss: 1.6485 - accuracy: 0.6397
# Epoch 00060: saving model to ../Model_weights/Densenet7\
# 100/100 [==============================] - 56s 544ms/step - loss: 1.6485 - accuracy: 0.6397 - val_loss: 1.1445 - val_accuracy: 0.7937
# 0:55:14.501670

# %%
plot_multiple_histories(densenet_total_history, ['loss', 'val_loss'])

# %%
plot_multiple_histories(densenet_total_history, ['accuracy','val_accuracy'])

# %%
plot_multiple_histories(densenet_total_history, ['accuracy','val_accuracy'])

# %%
plot_multiple_histories(densenet_total_history, ['loss', 'val_loss'])

# %%
plot_multiple_histories(densenet_total_history, ['accuracy','val_accuracy'])

# %%
plot_multiple_histories(densenet_total_history, ['accuracy','val_accuracy'])

# %%
temp_generator = test_datagen.flow_from_directory(
        validation_path,
        target_size=img_size,
        batch_size=2560,
        shuffle=True,
        class_mode='categorical')
# Out:
# Found 6123 images belonging to 80 classes.

# %%
sns.set(rc={'figure.figsize':(50,50)})
sns.set(font_scale = 20)

# %% [markdown]
# # More models:

# %%
def plot_confusion(model):
    imgs, label = next(validation_generator)
    preds = model.predict(imgs).argmax(axis=-1)
    label = label.argmax(axis=-1)
    print(preds == label)
    CM = confusion_matrix(label, preds)
    ax = plt.axes()
    sns.heatmap(CM, annot=True, 
               annot_kws={"size": 10}, ax = ax)
    ax.set_title('Confusion matrix')
    plt.show()
    
res = plot_confusion(densenet)
# Out:
# [False False False  True False  True  True  True False False False False
#   True  True  True  True  True  True  True  True False False False False
#   True  True  True  True  True False  True  True False  True False False
#  False  True  True False False  True  True  True False  True  True  True
#   True False  True  True  True False False  True  True False  True False
#  False  True  True  True]

# %% [markdown]
# # Predict the test set
# We also have to predict the real test set and save the results to upload to kaggle

# %%
def predict_test(model):
    preds = model.predict(test_generator)
    preds_cls_idx = preds.argmax(axis=-1)
    idx_to_cls = {v: k for k, v in train_generator.class_indices.items()}
    preds_cls = np.vectorize(idx_to_cls.get)(preds_cls_idx)
    filenames_to_cls = list(zip(test_generator.filenames, preds_cls))
    
    l = []
    n = []
    for p in filenames_to_cls:
        n.append(p[0].split("\\")[-1])
        l.append(p[1])
    return pd.DataFrame(list(zip(n, l)), columns=['img_name','label'])

res = predict_test(densenet)
res.to_csv("sample_submission.csv", index=False)
